# %%
# 連接至雲端硬碟
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17521, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 17521 (delta 14), reused 12 (delta 10), pack-reused 17491 (from 3)
# Receiving objects: 100% (17521/17521), 16.65 MiB | 30.73 MiB/s, done.
# Resolving deltas: 100% (12005/12005), done.

# %%
# 進入yolov5資料夾並安裝相關套件
# %cd yolov5
# !pip install -r requirements.txt
# %cd
# Out:
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# 複製dataset檔案至colab
# !rm -rf /content/data
# !mkdir /content/data
# !cp /content/drive/MyDrive/dataset.zip /content/data/dataset.zip

# %%
# 解壓縮檔案
# !unzip /content/data/dataset.zip -d /content/data
# !rm -rf /content/data/dataset.zip
# Out:
# Archive:  /content/data/dataset.zip
#    creating: /content/data/dataset/
#    creating: /content/data/dataset/images/
#    creating: /content/data/dataset/images/test/
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_47_59_Pro (3).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_47_59_Pro (4).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_10_Pro (2).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_14_Pro.jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_15_Pro (2).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_18_Pro (5).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_19_Pro (4).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_28_Pro (5).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_29_Pro (2).jpg
#   inflating: /content/data/dataset/images/test/WIN_20250704_14_48_30_Pro (4).jpg
# ...

# %%
import shutil

# 要移動的目錄路徑
source_dir = '/content/data/dataset'
# 目標位置的目錄路徑
target_dir = '/content/yolov5/data'

shutil.move(source_dir, target_dir)
# Out:
# '/content/yolov5/data/dataset'

# %%
# %cd /content/yolov5
# !python train.py --cfg models/yolov5s.yaml --img-size 640 --batch-size 64 --data /content/yolov5/data/coco.yaml --weights pre_trained_weights/yolov5s6.pt --device 0
# %cd ..
# Out:
# /content/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-04 08:58:23.372362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751619503.394459    2054 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751619503.400681    2054 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# ...

# %%
# 打包訓練結果
# !zip -r training_result.zip /content/yolov5/runs
# Out:
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 50%)
#   adding: content/yolov5/runs/train/exp/events.out.tfevents.1751619390.43dc775a5318.1484.0 (deflated 9%)
#   adding: content/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/weights/last.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp2/weights/best.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp2/train_batch0.jpg (deflated 14%)
#   adding: content/yolov5/runs/train/exp2/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp2/results.csv (deflated 83%)
# ...

# %%
# 下載訓練結果
from google.colab import files
files.download("training_result.zip")
